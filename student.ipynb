# %% [markdown]
# <a href="https://colab.research.google.com/github/SamanthaR9/SamanthaR9/blob/main/student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==== SETUP: install and import libraries ====

# Run this cell once whenever you (re)connect to the runtime.



# 1. Install any libraries

# !pip install pandas matplotlib seaborn --quiet

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %%
pd.set_option("display.max_rows", 10)

sns.set(style="whitegrid")



print("Setup complete")
# Out:
# Setup complete

# %%
# Connect this notebook to your Google Drive

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files

import pandas as pd

uploaded = files.upload() # you chose "student.csv from choose files – below tab

full_path = '/content/student.csv' # match the name shown after upload.
# Out:
#      <input type="file" id="files-71ef89a8-fb22-4e11-a201-70d618de715c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-71ef89a8-fb22-4e11-a201-70d618de715c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/student.csv')            # file that appears on the left

# %%
print("Dataset loaded: Student.csv")
# Out:
# Dataset loaded: Student.csv

# %%
print(f"Shape: {df.shape}")
# Out:
# Shape: (35, 5)

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    34 non-null     object
#  2   class   34 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  33 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
df.describe()
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
df["name"]
# Out:
# 0        John Deo
# 1        Max Ruin
# 2          Arnold
# 3      Krish Star
# 4       John Mike
#          ...
# 30    Marry Toeey
# 31      Binn Rott
# 32      Kenn Rein
# 33       Gain Toe
# 34     Rows Noump
# Name: name, Length: 35, dtype: object

# %%
df[["name", "mark"]]
# Out:
#            name  mark
# 0      John Deo    75
# 1      Max Ruin    85
# 2        Arnold    55
# 3    Krish Star    60
# 4     John Mike    60
# ..          ...   ...
# 30  Marry Toeey    88
# 31    Binn Rott    90
# 32    Kenn Rein    96
# 33     Gain Toe    69
# 34   Rows Noump    88
#
# [35 rows x 2 columns]

# %%
df[0:3]
# Out:
#    id      name  class  mark  gender
# 0   1  John Deo   Four    75  female
# 1   2  Max Ruin  Three    85    male
# 2   3    Arnold  Three    55    male

# %%
df.head(3)
# Out:
#    id      name  class  mark  gender
# 0   1  John Deo   Four    75  female
# 1   2  Max Ruin  Three    85    male
# 2   3    Arnold  Three    55    male

# %%
df[df['class'] == 'Four']
# Out:
#     id         name class  mark  gender
# 0    1     John Deo  Four    75  female
# 3    4   Krish Star  Four    60  female
# 4    5    John Mike  Four    60  female
# 5    6    Alex John  Four    55    male
# 9   10     Big John  Four    55  female
# 15  16        Gimmy  Four    88    male
# 20  21   Babby John  Four    69  female
# 30  31  Marry Toeey  Four    88    male

# %%
df["passed"] = df["mark"] >=60

# %%
df["passed"] = df["mark"] >=60
print(df)
# Out:
#     id         name  class  mark  gender  passed
# 0    1     John Deo   Four    75  female    True
# 1    2     Max Ruin  Three    85    male    True
# 2    3       Arnold  Three    55    male   False
# 3    4   Krish Star   Four    60  female    True
# 4    5    John Mike   Four    60  female    True
# ..  ..          ...    ...   ...     ...     ...
# 30  31  Marry Toeey   Four    88    male    True
# 31  32    Binn Rott  Seven    90  female    True
# 32  33    Kenn Rein    Six    96  female    True
# 33  34     Gain Toe  Seven    69    male    True
# 34  35   Rows Noump    Six    88  female    True
#
# [35 rows x 6 columns]

# %%
df.rename(columns={"mark": "score"}, inplace=True)
print(df)
# Out:
#     id         name  class  score  gender  passed
# 0    1     John Deo   Four     75  female    True
# 1    2     Max Ruin  Three     85    male    True
# 2    3       Arnold  Three     55    male   False
# 3    4   Krish Star   Four     60  female    True
# 4    5    John Mike   Four     60  female    True
# ..  ..          ...    ...    ...     ...     ...
# 30  31  Marry Toeey   Four     88    male    True
# 31  32    Binn Rott  Seven     90  female    True
# 32  33    Kenn Rein    Six     96  female    True
# 33  34     Gain Toe  Seven     69    male    True
# 34  35   Rows Noump    Six     88  female    True
#
# [35 rows x 6 columns]

# %%
df.drop("passed", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9207/102682471.py in <cell line: 0>()
# ----> 1 df.drop("passed", axis=1, inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.head()
# Out:
#    id        name  class  score  gender
# 0   1    John Deo   Four     75  female
# 1   2    Max Ruin  Three     85    male
# 2   3      Arnold  Three     55    male
# 3   4  Krish Star   Four     60  female
# 4   5   John Mike   Four     60  female

# %%
df.columns
# Out:
# Index(['id', 'name', 'class', 'score', 'gender'], dtype='object')

# %%
df['passed'] = df['score'] >= 60

# %%
df.head()
# Out:
#    id        name  class  score  gender  passed
# 0   1    John Deo   Four     75  female    True
# 1   2    Max Ruin  Three     85    male    True
# 2   3      Arnold  Three     55    male   False
# 3   4  Krish Star   Four     60  female    True
# 4   5   John Mike   Four     60  female    True

# %%
df.drop('passed', axis=1, inplace=True)

# %%
df.head()
# Out:
#    id        name  class  score  gender
# 0   1    John Deo   Four     75  female
# 1   2    Max Ruin  Three     85    male
# 2   3      Arnold  Three     55    male
# 3   4  Krish Star   Four     60  female
# 4   5   John Mike   Four     60  female

# %%
df.groupby("class")["score"].mean()
# Out:
# class
# Eight    79.000000
# Fifth    78.000000
# Five     80.000000
# Four     68.750000
# Nine     41.500000
# Seven    77.600000
# Six      82.571429
# Three    73.666667
# Name: score, dtype: float64

# %%
df["class"].value_counts()
# Out:
# class
# Seven    10
# Four      8
# Six       7
# Three     3
# Nine      2
# Five      2
# Fifth     1
# Eight     1
# Name: count, dtype: int64

# %%
df.groupby("gender")["score"].mean()
# Out:
# gender
# female    77.312500
# male      71.588235
# Name: score, dtype: float64

# %%
pd.pivot_table(df, values="score", index="class", columns="gender", aggfunc="mean")
# Out:
# gender  female  male
# class
# Eight      NaN  79.0
# Fifth      NaN  78.0
# Five       NaN  80.0
# Four      63.8  77.0
# Nine      65.0  18.0
# Seven     81.4  73.8
# Six       89.2  54.0
# Three      NaN  70.0

# %%
import numpy as np

df["grade"] = np.where(df["score"] >= 85, "A",
                np.where(df["score"] >= 70, "B",
                np.where(df["score"] >= 60, "C", "D")))

# %%
print(df)
# Out:
#     id         name  class  score  gender grade
# 0    1     John Deo   Four     75  female     B
# 1    2     Max Ruin  Three     85    male     A
# 2    3       Arnold  Three     55    male     D
# 3    4   Krish Star   Four     60  female     C
# 4    5    John Mike   Four     60  female     C
# ..  ..          ...    ...    ...     ...   ...
# 30  31  Marry Toeey   Four     88    male     A
# 31  32    Binn Rott  Seven     90  female     A
# 32  33    Kenn Rein    Six     96  female     A
# 33  34     Gain Toe  Seven     69    male     C
# 34  35   Rows Noump    Six     88  female     A
#
# [35 rows x 6 columns]

# %%
df.sort_values(by="score", ascending=False)
# Out:
#     id         name  class  score  gender grade
# 32  33    Kenn Rein    Six     96  female     A
# 11  12        Recky    Six     94  female     A
# 31  32    Binn Rott  Seven     90  female     A
# 10  11       Ronald    Six     89  female     A
# 30  31  Marry Toeey   Four     88    male     A
# ..  ..          ...    ...    ...     ...   ...
# 9   10     Big John   Four     55  female     D
# 21  22       Reggid  Seven     55  female     D
# 28  29  Tess Played  Seven     55    male     D
# 16  17        Tumyu    Six     54    male     D
# 18  19        Tinny   Nine     18    male     D
#
# [35 rows x 6 columns]

# %%
df.to_csv("updated_data.csv", index=False)

# %%
import os
os.listdir()
# Out:
# ['.config', 'drive', 'updated_data.csv', 'student.csv', 'sample_data']

# %%
import matplotlib.pyplot as plt

df.groupby("class")["score"].mean().plot(kind="bar")
plt.title("Average Score per Class")
plt.ylabel("Score")
plt.show()

# %%
df["score"].plot(kind="hist", bins=10)
plt.title("Score Distribution")
plt.xlabel("Score")
plt.show()

# %%
import matplotlib.pyplot as plt

df.groupby("gender")["score"].mean().plot(kind="bar")
plt.title("Average Score by Gender")
plt.ylabel("Average Score")
plt.show()

# %%
df["grade"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.title("Grade Distribution")
plt.ylabel("")
plt.show()
